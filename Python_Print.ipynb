# %%
a = 10
b = 12
a
b
# Out:
# 12

# %%
a = 10
b = 20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(20)
print(10,20)
print(10,20,'python')
# Out:
# 10
# 20
# 10 20
# 10 20 python

# %%
num1 = 10
num2 = 20
add= num1+num2
print(add)
# Out:
# 30

# %%
num1 = 10
num2 = 20
add= num1+num2
print('the sum of', num1, 'and', num2 ,'is', add)
# Out:
# the sum of 10 and 20 is 30

# %%
name='Python' 
age=20
city='hyd'
print('Hello my name is',name , 'I am',age,'years','I am from',city)
# Out:
# Hello my name is Python I am 20 years I am from hyd

# %%
num1 = 20
num2 = 30
add= num1+num2
print('The sum of {} and {} is  {}'.format(num1,num2,add))
# Out:
# The sum of 20 and 30 is  50

# %%
name = 'Asmath'
age = 10
city = 'hyd'
print('My name is {} I am {} years and I am from {}'.format(name,age,city))
# Out:
# My name is Asmath I am 10 years and I am from hyd

# %%
num1 = 26
num2 = 34
num3 = 45
avg1 = (num1+num2+num3)/3
avg2 = round((num1+num2+num3)/3,2)
print('The average of {},{} and {} is {} or {}'.format(num1,num2,num3,avg1,avg2))
# Out:
# The average of 26,34 and 45 is 35.0 or 35.0

# %%
num1 = 20
num2 = 30
add = num1+num2
print(f'The sum of {num1} and {num2} is {add}')
# Out:
# The sum of 20 and 30 is 50

# %%
name = 'Asmath'
age = 10
city = 'Hyd'
print(f'I am {name}, my age is {age} years and I am from {city}')
# Out:
# I am Asmath, my age is 10 years and I am from Hyd

# %%
print('hello')
print('good morning')
# Out:
# hello
# good morning

# %%
print('hello' , end =' ')
print ('good morning')
# Out:
# hello good morning

# %%
print('hello','hi','how','are','you',sep = '*')
# Out:
# hello*hi*how*are*you

# %%
print('hello','hi','how','are','you',sep = '')
# Out:
# hellohihowareyou

# %%
print('hello','hi','how','are','you',sep = ' ')
# Out:
# hello hi how are you

# %%
print(3,sep = '.')
# Out:
# 3

# %%
print(3,'.')
# Out:
# 3 .

# %%
print(3,'.',sep = '')
# Out:
# 3.
